# %% [markdown]
# 1.Import pandas

# %%
import pandas as pd

# %%
df = pd.read_csv(
"https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 2.Remove 1st numbering column

# %%
df = pd.read_csv(
"https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv",index_col="PassengerId"
)

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df = pd.read_csv(
"https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv",header=1
)

# %%
df
# Out:
#        1  0  3                            Braund, Mr. Owen Harris    male  \
# 0      2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 1      3  1  3                             Heikkinen, Miss. Laina  female
# 2      4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 3      5  0  3                           Allen, Mr. William Henry    male
# 4      6  0  3                                   Moran, Mr. James    male
# ..   ... .. ..                                                ...     ...
# 885  887  0  2                              Montvila, Rev. Juozas    male
# 886  888  1  1                       Graham, Miss. Margaret Edith  female
# 887  889  0  3           Johnston, Miss. Catherine Helen "Carrie"  female
# 888  890  1  1                              Behr, Mr. Karl Howell    male
# 889  891  0  3                                Dooley, Mr. Patrick    male
#
#        22  1.1  0.1         A/5 21171     7.25 Unnamed: 10  S
# ...

# %% [markdown]
# import only selected columns

# %%
df = pd.read_csv(
"https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv",usecols=['PassengerId', 'Survived', 'Pclass']
)

# %%
df
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
# [891 rows x 3 columns]

# %% [markdown]
# Loading a Huge dataset in chunk

# %%
dfs=pd.read_csv(
"https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv",chunksize=50
)

# %%
for df in dfs:
    print(df.shape)
# Out:
# (50, 12)
# (50, 12)
# (50, 12)
# (50, 12)
# (50, 12)
# (50, 12)
# (50, 12)
# (50, 12)
# (50, 12)
# (50, 12)
# (50, 12)
# (50, 12)
# (50, 12)
# (50, 12)
# (50, 12)
# (50, 12)
# (50, 12)
# (41, 12)
